# %% [markdown]
# ## Predicting Fatal Accidents

# %%
from path import Path
import pandas as pd

# %%
data = Path('Resources/Accidents20.csv')
df = pd.read_csv(data)
df.head()
# Out:
#         CaseNum  Region#   Area Type  Month#    Month  Year        Day  Hour  \
# 0  2.020000e+11        4  Rural Area       1  January  2020  Wednesday     8
# 1  2.020000e+11        3  Urban Area       1  January  2020  Wednesday     1
# 2  2.020000e+11        3  Urban Area       1  January  2020  Wednesday    13
# 3  2.020000e+11        4  Rural Area       1  January  2020  Wednesday    14
# 4  2.020000e+11        1  Rural Area       1  January  2020  Wednesday    17
#
#    Minute  Outcome         Outcome Description           Night/Day  \
# 0      19        0      No Apparent Injury (O)            Daylight
# 1       0        2  Suspected Minor Injury (B)  Dark - Not Lighted
# 2      17        0      No Apparent Injury (O)            Daylight
# 3      59        0      No Apparent Injury (O)            Daylight
# 4       8        0      No Apparent Injury (O)  Dark - Not Lighted
#
#   Weather Condition
# 0            Cloudy
# 1             Clear
# 2             Clear
# ...

# %%
df.drop(columns=["CaseNum", "Month#",""], inplace=True)

# %%
# make dummies for rating
dummy_df = pd.get_dummies(df, columns=["rating"])
